# %% [markdown]
# <a href="https://colab.research.google.com/github/FDMasangkay/CPE-031-VDA-CPE-21S4/blob/main/Exercise7/Exercise7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Laboratory Exercise

# %%
import pandas as pd

# %%
data = {
    'apples': [3, 2, 0, 1],
    'oranges': [0, 3, 7, 2]
}

# %%
purchases = pd.DataFrame(data)

# %%
purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %%
purchases = pd.DataFrame(data, index = ['June', 'Robert', 'Lily', 'David'])

# %%
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
purchases.to_csv('fruits.csv')

# %%
purchases.to_excel('fruits.xlsx')

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-583fd26d-f01c-446d-8fbf-24afb10ee6e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-583fd26d-f01c-446d-8fbf-24afb10ee6e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("fruits.csv")

# %%
purchases = pd.DataFrame(data)

# %%
print (purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1232c24-c1d6-4f6a-9267-863d141bde1a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1232c24-c1d6-4f6a-9267-863d141bde1a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Loading the data from excel file
data = pd.read_excel("fruits.xlsx")

# %%
purchases = pd.DataFrame(data)

# %%
print(purchases)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %%
data.head(3)
# Out:
#   Unnamed: 0  apples  oranges
# 0       June       3        0
# 1     Robert       2        3
# 2       Lily       0        7

# %%
data.tail(3)
# Out:
#   Unnamed: 0  apples  oranges
# 1     Robert       2        3
# 2       Lily       0        7
# 3      David       1        2

# %% [markdown]
# ## Laboratory Manual Activity: Creating and Accessing Panda DataFrames

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fdf2133e-b21d-4491-9126-56741cfcbde7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdf2133e-b21d-4491-9126-56741cfcbde7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("LoL_champions - Data only.csv")

# %%
LoL_champions = pd.DataFrame(data)

# %%
LoL_champions
# Out:
#           Name           Tags     Role Range type Resourse type  Base HP  \
# 0       Aatrox  Tank, Fighter      Top      Melee    Blood Well      650
# 1      Alistar   Tank,Support  Support      Melee          Mana      685
# 2        Amumu   Tank,Support   Jungle      Melee          Mana      685
# 3   Blitzcrank  Tank, Support  Support      Melee          Mana      600
# 4        Braum  Tank, Support  Support      Melee          Mana      610
# 5      Camille   Tank,Fighter      Top      Melee          Mana      670
# 6     Cho'Gath   Tank,Fighter      Top      Melee          Mana      644
# 7       Darius   Tank,Fighter      Top      Melee          Mana      652
# 8    Dr. Mundo   Tank,Fighter      Top      Melee           NaN      613
# 9        Galio     Tank, Mage   Middle      Melee          Mana      632
# 10       Garen   Tank,Fighter      Top      Melee           NaN      690
# 11        Gnar   Tank,Fighter      Top     Ranged          Rage      540
# ...

# %%
# Creating a dictionaries of list from the original dataset
champion_data = {
    "Name": ["Aatrox", "Alistar", "Amumu", "Blitzcrank", "Braum"],
    # observation - Under the variable name the data are "Aatrox", "Alistar", "Amumu", "Blitzcrank", "Braum"
    "Tags": [["Tank", "Fighter"], ["Tank", "Support"], ["Tank", "Support"], ["Tank", "Support"], ["Tank", "Support"]],
    "Role": ["Top", "Support", "Jungle", "Support", "Support"],
    "Range type": ["Melee", "Melee", "Melee", "Melee", "Melee"],
    "Resource type": ["Blood Well", "Mana", "Mana", "Mana", "Mana"],
    "Base HP": [650, 685, 685, 600, 610],
    "Movement speed": [345, 330, 335, 325, 335],
    "Base armor": [38, 47, 33, 37, 47],
    "Base magic resistance": [32, 32, 32, 32, 32],
    "Attack range": [175, 125, 125, 125, 125],
    "HP regeneration": [3, 8.5, 9, 7.5, 8.5],
    "Attack damage": [60, 62, 57, 62, 55],
    "Attack speed": [0.651, 0.625, 0.736, 0.625, 0.644]
    # observation - Under the variable Attack speed the data are 0.651, 0.625, 0.736, 0.625, 0.644
}

# %%
df = pd.DataFrame(champion_data)  # observation - creating avariable to store the data frame from champion_list

# %%
df # Observation - Printing the df
# Out:
#          Name             Tags     Role Range type Resource type  Base HP  \
# 0      Aatrox  [Tank, Fighter]      Top      Melee    Blood Well      650
# 1     Alistar  [Tank, Support]  Support      Melee          Mana      685
# 2       Amumu  [Tank, Support]   Jungle      Melee          Mana      685
# 3  Blitzcrank  [Tank, Support]  Support      Melee          Mana      600
# 4       Braum  [Tank, Support]  Support      Melee          Mana      610
#
#    Movement speed  Base armor  Base magic resistance  Attack range  \
# 0             345          38                     32           175
# 1             330          47                     32           125
# 2             335          33                     32           125
# 3             325          37                     32           125
# 4             335          47                     32           125
#
#    HP regeneration  Attack damage  Attack speed
# 0              3.0             60         0.651
# ...

# %%
# Creating a list of dictionaries from the original dataset
champion_list = [
    {"Name": "Aatrox", "Tags": ["Tank", "Fighter"], "Role": "Top", "Range type": "Melee", "Resource type": "Blood Well", "Base HP": 650, "Movement speed": 345, "Base armor": 38, "Base magic resistance": 32, "Attack range": 175, "HP regeneration": 3, "Attack damage": 60, "Attack speed": 0.651},
    # observation - The list was consist of Name, Tags, Role, Range type, Resource type, Base Hp, and so on.
    {"Name": "Alistar", "Tags": ["Tank", "Support"], "Role": "Support", "Range type": "Melee", "Resource type": "Mana", "Base HP": 685, "Movement speed": 330, "Base armor": 47, "Base magic resistance": 32, "Attack range": 125, "HP regeneration": 8.5, "Attack damage": 62, "Attack speed": 0.625},
    {"Name": "Amumu", "Tags": ["Tank", "Support"], "Role": "Jungle", "Range type": "Melee", "Resource type": "Mana", "Base HP": 685, "Movement speed": 335, "Base armor": 33, "Base magic resistance": 32, "Attack range": 125, "HP regeneration": 9, "Attack damage": 57, "Attack speed": 0.736},
    {"Name": "Blitzcrank", "Tags": ["Tank", "Support"], "Role": "Support", "Range type": "Melee", "Resource type": "Mana", "Base HP": 600, "Movement speed": 325, "Base armor": 37, "Base magic resistance": 32, "Attack range": 125, "HP regeneration": 7.5, "Attack damage": 62, "Attack speed": 0.625},
    {"Name": "Braum", "Tags": ["Tank", "Support"], "Role": "Support", "Range type": "Melee", "Resource type": "Mana", "Base HP": 610, "Movement speed": 335, "Base armor": 47, "Base magic resistance": 32, "Attack range": 125, "HP regeneration": 8.5, "Attack damage": 55, "Attack speed": 0.644}
] # observation - The list of dictionaies was created

# %%
df_from_list = pd.DataFrame(champion_list) # observation - creating avariable to store the data frame from champion_list

# %%
df_from_list # Observation - Printing the df_from_list
# Out:
#          Name             Tags     Role Range type Resource type  Base HP  \
# 0      Aatrox  [Tank, Fighter]      Top      Melee    Blood Well      650
# 1     Alistar  [Tank, Support]  Support      Melee          Mana      685
# 2       Amumu  [Tank, Support]   Jungle      Melee          Mana      685
# 3  Blitzcrank  [Tank, Support]  Support      Melee          Mana      600
# 4       Braum  [Tank, Support]  Support      Melee          Mana      610
#
#    Movement speed  Base armor  Base magic resistance  Attack range  \
# 0             345          38                     32           175
# 1             330          47                     32           125
# 2             335          33                     32           125
# 3             325          37                     32           125
# 4             335          47                     32           125
#
#    HP regeneration  Attack damage  Attack speed
# 0              3.0             60         0.651
# ...

# %%
single_column = df_from_list['Name']

# %%
single_column
# Out:
# 0        Aatrox
# 1       Alistar
# 2         Amumu
# 3    Blitzcrank
# 4         Braum
# Name: Name, dtype: object

# %%
multiple_columns = df_from_list[['Name', 'Base HP', 'Attack damage']]

# %%
multiple_columns
# Out:
#          Name  Base HP  Attack damage
# 0      Aatrox      650             60
# 1     Alistar      685             62
# 2       Amumu      685             57
# 3  Blitzcrank      600             62
# 4       Braum      610             55

# %%
# Selecting a single row using pandas indexing (loc)
single_row_pandas = df_from_list.loc[2]  # Selecting the 3rd row (Amumu)
single_row_pandas
# Out:
# Name                               Amumu
# Tags                     [Tank, Support]
# Role                              Jungle
# Range type                         Melee
# Resource type                       Mana
# Base HP                              685
# Movement speed                       335
# Base armor                            33
# Base magic resistance                 32
# Attack range                         125
# HP regeneration                      9.0
# Attack damage                         57
# Attack speed                       0.736
# Name: 2, dtype: object

# %%
# Selecting multiple rows using pandas indexing (loc)
multiple_rows_pandas = df_from_list.loc[1:4]  # Selecting the 2nd to 4th row (Alistar to Blitzcrank)
multiple_rows_pandas
# Out:
#          Name             Tags     Role Range type Resource type  Base HP  \
# 1     Alistar  [Tank, Support]  Support      Melee          Mana      685
# 2       Amumu  [Tank, Support]   Jungle      Melee          Mana      685
# 3  Blitzcrank  [Tank, Support]  Support      Melee          Mana      600
# 4       Braum  [Tank, Support]  Support      Melee          Mana      610
#
#    Movement speed  Base armor  Base magic resistance  Attack range  \
# 1             330          47                     32           125
# 2             335          33                     32           125
# 3             325          37                     32           125
# 4             335          47                     32           125
#
#    HP regeneration  Attack damage  Attack speed
# 1              8.5             62         0.625
# 2              9.0             57         0.736
# 3              7.5             62         0.625
# 4              8.5             55         0.644

# %%
# Selecting a single row using Python indexing (index-based)
single_row_python = df_from_list[1:2]  # Selecting the 2nd row (Alistar)
single_row_python
# Out:
#       Name             Tags     Role Range type Resource type  Base HP  \
# 1  Alistar  [Tank, Support]  Support      Melee          Mana      685
#
#    Movement speed  Base armor  Base magic resistance  Attack range  \
# 1             330          47                     32           125
#
#    HP regeneration  Attack damage  Attack speed
# 1              8.5             62         0.625

# %%
# Selecting multiple rows using Python indexing (index-based)
multiple_rows_python = df_from_list[1:4]  # Selecting rows from index 1 to 3 (Alistar to Blitzcrank)
multiple_rows_python
# Out:
#          Name             Tags     Role Range type Resource type  Base HP  \
# 1     Alistar  [Tank, Support]  Support      Melee          Mana      685
# 2       Amumu  [Tank, Support]   Jungle      Melee          Mana      685
# 3  Blitzcrank  [Tank, Support]  Support      Melee          Mana      600
#
#    Movement speed  Base armor  Base magic resistance  Attack range  \
# 1             330          47                     32           125
# 2             335          33                     32           125
# 3             325          37                     32           125
#
#    HP regeneration  Attack damage  Attack speed
# 1              8.5             62         0.625
# 2              9.0             57         0.736
# 3              7.5             62         0.625
