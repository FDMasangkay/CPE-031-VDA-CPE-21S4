# %% [markdown]
# <a href="https://colab.research.google.com/github/FDMasangkay/CPE-031-VDA-CPE-21S4/blob/main/Exercise_10_%26_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# generate data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 5, 4, 5])

# %%
# calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x, y, 1)

# %%
# calculate the predicted values of y using the regression line equation
y_pred = slope * x + intercept

# %%
# plot the original data points and the regression line
plt.scatter(x, y)
plt.plot(x, y_pred, color='red')
plt.show()

# %%
# creating vectors X and Y
x = np.linspace(-2, 2, 100)
y = x ** 2

fig = plt.figure(figsize = (10, 5))

plt.plot(x, y)
plt.show()

# %% [markdown]
# ### Exercise 10

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26e002d1-cf39-49cb-89e5-1eb91902b71e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26e002d1-cf39-49cb-89e5-1eb91902b71e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("VDA Regression Analysis - Sheet3.csv", index_col=None)

# %%
data = pd.DataFrame(data)
data
# Out:
#    Profiecieny Exam Score  Course Grade
# 0                      60            70
# 1                      90            95
# 2                      70            70
# 3                      85            75
# 4                      80            90
# 5                      65            75
# 6                      75            75
# 7                      60            60
# 8                      75            80
# 9                      70            65

# %%
x = data['Profiecieny Exam Score']
y = data['Course Grade']

# Calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x, y, 1)

# Calculate the predicted values of y using the regression line equation
y_predicted = slope * x + intercept

# Plot the original data points and the regression line
plt.scatter(x, y, label="Original Data")
plt.plot(x, y_predicted, color='red', label="Regression Line")
plt.xlabel("Profiecieny Exam Score")
plt.ylabel("Course Grade")
plt.title("Scatter Plot with Regression Line")
plt.legend()
plt.show()

# %% [markdown]
# ### Exercise 11

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf070d44-9829-415a-a7a9-f66995f96c80" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf070d44-9829-415a-a7a9-f66995f96c80">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("VDA Regression Analysis - Sheet2.csv", index_col=None)

# %%
data = pd.DataFrame(data)
data
# Out:
#      x     y
# 0  0.5  1.90
# 1  1.0  1.50
# 2  1.3  1.20
# 3  1.6  1.00
# 4  2.0  0.80
# 5  2.2  0.78
# 6  2.5  0.65
# 7  3.1  0.46
# 8  3.9  0.30
# 9  4.4  0.23

# %%
x = data['x']
y = data['y']

# Calculate the slope and y-intercept of the regression line
slope, intercept = np.polyfit(x, y, 1)

# Calculate the predicted values of y using the regression line equation
y_predicted = slope * x + intercept

# Plot the original data points and the regression line
plt.scatter(x, y, label="Original Data")
plt.plot(x, y_predicted, color='red', label="Regression Line")
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("Scatter Plot with Regression Line")
plt.legend()
plt.show()

# %% [markdown]
# **Interpretation:**
#
# The scatter plot shows a negative correlation between the x and y variables, with the regression line indicating a downward trend. As x increases, y decreases, suggesting an inverse relationship.
