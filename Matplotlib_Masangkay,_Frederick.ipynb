# %% [markdown]
# <a href="https://colab.research.google.com/github/FDMasangkay/CPE-031-VDA-CPE-21S4/blob/main/Matplotlib_Masangkay%2C_Frederick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt #pyplot submodule and imported under plt alias
import numpy as np
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e8c91f2-7731-4a6c-9912-1e1bfbe1cd20" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e8c91f2-7731-4a6c-9912-1e1bfbe1cd20">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("Technological-Products-Sample-Data - Sheet1.csv")

# %%
data = pd.DataFrame(data)
data
# Out:
#         Brand       Device          Model Country of Origin Date of Release  \
# 0       Apple       iPhone     13 Pro Max     United States       9/24/2021
# 1     Samsung       Galaxy      S21 Ultra       South Korea       1/29/2021
# 2      Google        Pixel          6 Pro     United States      10/19/2021
# 3        Sony  PlayStation              5             Japan      11/12/2020
# 4   Microsoft      Surface       Laptop 4     United States       4/15/2021
# 5        Dell          XPS             13     United States       1/28/2021
# 6          HP      Spectre           x360     United States       4/16/2021
# 7      Lenovo     ThinkPad      X1 Carbon             China       2/15/2021
# 8        Asus          ROG   Zephyrus G14            Taiwan       3/15/2021
# 9        Acer     Predator     Helios 300            Taiwan       2/17/2021
# 10      Apple      MacBook    Pro 14-inch     United States      10/26/2021
# ...

# %% [markdown]
# ### A.) Read each device's date of release and Sales

# %%
plt.plot (data['Date of Release'], data['Price (USD)'])
plt.title("Line Plot Example")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### B.) Get the total sales and show line plot

# %%
plt.plot (data['Date of Release'], data['Price (USD)'], linestyle = 'dotted', color = 'red', label = 'Prices', marker = 'o', linewidth= 3)
plt.title("Line Plot Example")
plt.xlabel("Year")
plt.ylabel("Sales")
plt.xticks(rotation = 90)
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# ### C.) Read all product sales data and show it using a multiline plot. Label them

# %% [markdown]
# ### D.)

# %% [markdown]
# ### E.) Read each device and show it using the histogram to see the most common Country of Origin. Label them.

# %%
g = np.array([14, 3, 2, 4, 6, 1])
Origin = ["United States", "South Korea", "Japan", "China", "Taiwan", "Malaysia"]


plt.bar(Origin, g)
plt.xlabel('Country of Origin')
plt.ylabel('Count')
plt.title('Count of Devices by Country of Origin')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.show()

# %% [markdown]
# ###F.) Create a pie chart that shows each brand Country of Origin. Label them

# %%
g = np.array([14, 3, 2, 4, 6, 1])
Origin = ["United States", "South Korea", "Japan", "China", "Taiwan", "Malaysia"]
plt.pie(g, labels=Origin, autopct='%1.1f%%')
plt.title('Country of Origin for Devices')
plt.legend(title="Country of Origin", labels=Origin, loc="upper left")
plt.show()
