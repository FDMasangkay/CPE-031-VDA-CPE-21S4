# %% [markdown]
# <a href="https://colab.research.google.com/github/FDMasangkay/CPE-031-VDA-CPE-21S4/blob/main/Exercise_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib # adding module

# %%
print (matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt #pyplot submodule and imported under plt alias
import numpy as np

# %%
xpoints = np.array([0, 6]) # plotting x and y points
ypoints = np.array([0, 250])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1,3]) # plotting x and y points
ypoints = np.array([8, 10])

# %%
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# Draw a line in a diagram from position (1,3) to position (8,10)

# %% [markdown]
# Plotting without line
#
# - To plot only the markers, 'o' means 'rings'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints = np.array ([1, 2, 6, 8])
ypoints = np.array ([3, 8, 1, 10])

# %% [markdown]
# ### Multiple Points

# %%
plt.plot(xpoints, ypoints) # plot() is used to draw points
plt.show()

# %%
ypoints = np.array ([3, 8, 1, 10])

# %%
plt.plot(xpoints, ypoints, marker = 'o')
plt.show()

# %%
ypoints = np.array ([3, 8, 1, 10])

# %%
plt.plot(ypoints, 'o:c')
plt.show()

# %%
ypoints = np.array ([3, 8, 1, 10])

# %%
plt.plot(ypoints, 'o:c', ms = 15)
plt.show()

# %%
ypoints = np.array ([3, 8, 1, 10])

# %%
plt.plot(ypoints, 'o:b', ms = 10, mec = '')
plt.show()

# %% [markdown]
# ### Marker Face Color

# %%
# Plotting x and y points
ypoints = np.array ([3, 8, 1, 10])

# %%
plt.plot(ypoints, 'o:b', ms = 10, mec = 'green', mfc = 'red', linestyle = 'solid')
plt.show()
# Out:
# <ipython-input-59-236930ea3927>:1: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "o:b" (-> linestyle=':'). The keyword argument will take precedence.
#   plt.plot(ypoints, 'o:b', ms = 10, mec = 'green', mfc = 'red', linestyle = 'solid')

# %%
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %% [markdown]
# ### Matplot Labels and TItle - You can use the xlabel() and ylabel()

# %%
xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([3, 8, 1, 10])

plt.plot(xpoints, ypoints, color = 'yellow')# plot () is used to draw points

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km") # labels
plt.ylabel("Speed in km/s")
plt.show()

# %% [markdown]
# ### Matplot Grid - You can use grid () to add grid lines

# %%
# select grid lines to display
xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([3, 8, 1, 10])

plt.plot(xpoints, ypoints)# plot () is used to draw points

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km") # labels
plt.ylabel("Speed in km/s")
plt.grid(axis = 'y')
plt.show()

# %%
# select grid lines to display
xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([3, 8, 1, 10])

plt.plot(xpoints, ypoints)# plot () is used to draw points

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km") # labels
plt.ylabel("Speed in km/s")
plt.grid(axis = 'x', linestyle = "--", linewidth = 0.50)
plt.show()

# %% [markdown]
# ### Show Multiple Plots

# %%
# plot 1
xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(xpoints, ypoints) # plot () is used to draw points

# plot 1
xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(xpoints, ypoints) # plot () is used to draw points

plt.grid(axis = 'x', linestyle = "--", linewidth = 0.50)
plt.show()

# %% [markdown]
# ### Matplot Scatter - The scatter function plots one dot for each observation

# %%
xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([3, 8, 1, 10])

plt.scatter(xpoints, ypoints)

xpoints = np.array ([1, 2, 6, 8]) # plotting x and y points
ypoints = np.array ([10, 20, 30, 40])

plt.scatter(xpoints, ypoints)

plt.show()

# %% [markdown]
# ### Matplotlib Bars
# - You can use the bar() to draw bars

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array (['Student1', 'Student2', 'Student3'])
y = np.array ([90, 85, 86])
plt.bar(x,y, color = '#f2e2a7')
plt.show()

# %% [markdown]
# ### Matplotlib Pie CHart - You can use pie() to draw pie chart

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
g = np.array([35, 25, 25, 15])
grader = ["Grade 1 = 35%", "Grade 2 = 25%", "Grade 3 = 25%", "Grade 4 = 15%"]
plt.pie(g, labels = grader)
plt.legend(title = "Grader", labels = grader, loc = "upper left")
plt.show()
